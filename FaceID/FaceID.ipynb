# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
import numpy as np
import os 
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
import random
from tqdm import tqdm

# %%
datadir = "/content/drive/MyDrive/FaceID"
categories=['CaoNguyen','HoangAnh','ThanhDung']
img_size=100
for category in categories:
  path=os.path.join(datadir,category)
  for img in os.listdir(path):
    img_array = cv.imread(os.path.join(path,img),cv.IMREAD_GRAYSCALE)
    new_array = cv.resize(img_array,(img_size,img_size))
    print(new_array)
    plt.imshow(new_array,cmap='gray')
    plt.show()
    break
  break
# Out:
# [[ 35  33  34 ...  37  29  33]
#  [ 37  39  34 ...  34  33  35]
#  [ 45  38  39 ...  72  78  80]
#  ...
#  [132 132 131 ... 117 105  60]
#  [132 130 134 ...  79 104 108]
#  [136 131 130 ... 112 101  97]]

# %%
#creating training data
training_data=[]
def create_traning_data():

  for category in categories:
    path = os.path.join(datadir,category)
    class_num = categories.index(category)

    for img in tqdm(os.listdir(path)):
      try:
        img_array = cv.imread(os.path.join(path,img),cv.IMREAD_GRAYSCALE)
        new_array = cv.resize(img_array,(img_size,img_size))
        training_data.append([new_array,class_num])
      except Exception as e:
        pass
create_traning_data()
print(len(training_data))
# Out:
# 100%|██████████| 30/30 [00:01<00:00, 21.73it/s]
# 100%|██████████| 30/30 [00:01<00:00, 22.02it/s]
# 100%|██████████| 30/30 [00:16<00:00,  1.79it/s]
# 90

# %%
#saving (x:picture), (y:label)
X=[]
y=[]
for features, label in training_data :
  X.append(features)
  y.append(label)
X=np.array(X).reshape(-1,img_size,img_size,1)
y=np.array(y)
print('X',X.shape)
print('y',y.shape)
# Out:
# X (90, 100, 100, 1)
# y (90,)

# %%
#saving x, y as file.pickle into drive
pickle_out=open("/content/drive/MyDrive/FaceID/save/X.pickle","wb")
pickle.dump(X,pickle_out)
pickle_out.close()

pickle_out=open("/content/drive/MyDrive/FaceID/save/y.pickle","wb")
pickle.dump(y,pickle_out)
pickle_out.close()

# %%
#BUILD MODEL
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.layers import Conv2D
from keras.layers.convolutional import MaxPooling2D
from tensorflow.keras.utils import to_categorical

# %%
pickle_in = open("/content/drive/MyDrive/FaceID/save/X.pickle","rb")
X= pickle.load(pickle_in)

pickle_in = open("//content/drive/MyDrive/FaceID/save/y.pickle","rb")
y= pickle.load(pickle_in)

X=X/255.0
print('X',X.shape)
print('y',y.shape)
# Out:
# X (90, 100, 100, 1)
# y (90,)

# %%
y= to_categorical(y,3)

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(100,100,1)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(3,activation='softmax'))

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD,Adam
opt =Adam()
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X,y,epochs=30,batch_size=64,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 6s 1s/step - loss: 7.2896 - accuracy: 0.2346 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 2/30
# 2/2 [==============================] - 5s 1s/step - loss: 1.8343 - accuracy: 0.2346 - val_loss: 0.2704 - val_accuracy: 1.0000
# Epoch 3/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.4279 - accuracy: 0.8889 - val_loss: 0.0598 - val_accuracy: 1.0000
# Epoch 4/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.4618 - accuracy: 0.9259 - val_loss: 0.5048 - val_accuracy: 1.0000
# Epoch 5/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.2935 - accuracy: 0.9753 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 6/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0944 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 7/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0428 - accuracy: 1.0000 - val_loss: 1.7292e-04 - val_accuracy: 1.0000
# Epoch 8/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 7.6853e-05 - val_accuracy: 1.0000
# Epoch 9/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 10/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 8.4771e-07 - val_accuracy: 1.0000
# Epoch 11/30
# 2/2 [==============================] - 5s 1s/step - loss: 4.1770e-04 - accuracy: 1.0000 - val_loss: 1.8544e-07 - val_accuracy: 1.0000
# Epoch 12/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 3.9736e-08 - val_accuracy: 1.0000
# Epoch 13/30
# 2/2 [==============================] - 5s 1s/step - loss: 3.7639e-04 - accuracy: 1.0000 - val_loss: 1.3245e-07 - val_accuracy: 1.0000
# Epoch 14/30
# 2/2 [==============================] - 5s 1s/step - loss: 3.9968e-04 - accuracy: 1.0000 - val_loss: 4.3710e-07 - val_accuracy: 1.0000
# Epoch 15/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.1126e-06 - val_accuracy: 1.0000
# Epoch 16/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 3.0465e-07 - val_accuracy: 1.0000
# Epoch 17/30
# 2/2 [==============================] - 5s 1s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.6491e-08 - val_accuracy: 1.0000
# Epoch 18/30
# 2/2 [==============================] - 5s 1s/step - loss: 2.0214e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 19/30
# 2/2 [==============================] - 5s 1s/step - loss: 7.5758e-06 - accuracy: 1.0000 - val_loss: 3.9736e-08 - val_accuracy: 1.0000
# Epoch 20/30
# 2/2 [==============================] - 5s 1s/step - loss: 3.6226e-04 - accuracy: 1.0000 - val_loss: 6.6227e-08 - val_accuracy: 1.0000
# Epoch 21/30
# 2/2 [==============================] - 5s 1s/step - loss: 8.3104e-05 - accuracy: 1.0000 - val_loss: 1.3245e-08 - val_accuracy: 1.0000
# Epoch 22/30
# 2/2 [==============================] - 5s 1s/step - loss: 3.7321e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 23/30
# 2/2 [==============================] - 5s 1s/step - loss: 9.1688e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 24/30
# 2/2 [==============================] - 5s 1s/step - loss: 6.8729e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 25/30
# 2/2 [==============================] - 5s 1s/step - loss: 7.4616e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 26/30
# 2/2 [==============================] - 5s 1s/step - loss: 8.0797e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 27/30
# 2/2 [==============================] - 5s 1s/step - loss: 8.6683e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 28/30
# 2/2 [==============================] - 5s 1s/step - loss: 9.1393e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 29/30
# 2/2 [==============================] - 5s 1s/step - loss: 9.4778e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 30/30
# 2/2 [==============================] - 5s 1s/step - loss: 9.7279e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %%
model.save('FaceID.h5')

# %%
img_test='/content/drive/MyDrive/FaceID/ThanhDung/ThanhDung (13).jpg'
categories=['CaoNguyen','HoangAnh','ThanhDung']
def prepare (filepath):
  img_size=100
  img_array=cv.imread(filepath, cv.IMREAD_GRAYSCALE)
  new_array=cv.resize(img_array,(100,100))
  new_array=new_array/255.0
  return new_array.reshape(-1,100,100,1)
plt.imshow(np.squeeze(prepare(img_test)),cmap='gray')
plt.show()

# %%
from keras.preprocessing.image import load_img,img_to_array
img1=load_img(img_test,target_size=(100,100))
img1_tensor=img_to_array(img1)
img1_tensor=np.expand_dims(img1_tensor,axis=0)
img1_tensor /= 255
plt.imshow(np.squeeze(img1_tensor))
plt.show()
prediction=model.predict([prepare(img_test)])
print('Prediction value',categories[int(np.argmax(prediction))])
# Out:
# Prediction value ThanhDung

# %%
from keras.models import load_model
# load and prepare the image
def load_image(filename):
	# load the image
	img = load_img(filename, target_size=(100, 100))	
	
	return img
labels = {0: 'CaoNguyen',
          1: 'HoangAnh', 
          2: 'ThanhDung',   
          }
model = load_model('FaceID.h5')
	# load model
img = load_image('/content/drive/MyDrive/FaceID/HoangAnh/HoangAnh (10).jpg')
plt.imshow(img)
img = img_to_array(img)
img.shape
img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
img = img.reshape(1,100,100,1)  
img.shape
result = model.predict(img)
print(result)
np.argmax(result) 
print('expectation',labels[np.argmax(result)])
# Out:
# [[0. 1. 0.]]
# expectation HoangAnh

# %%
from keras.models import load_model
# load and prepare the image
def load_image(filename):
	# load the image
	img = load_img(filename, target_size=(100, 100))	
	
	return img
labels = {0: 'CaoNguyen',
          1: 'HoangAnh', 
          2: 'ThanhDung',   
          }
model = load_model('FaceID.h5')
	# load model
img = load_image('/content/drive/MyDrive/FaceID/CaoNguyen/Nguyen (5).jpg')
plt.imshow(img)
img = img_to_array(img)
img.shape
img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
img = img.reshape(1,100,100,1)  
img.shape
result = model.predict(img)
print(result)
np.argmax(result) 
print('expectation',labels[np.argmax(result)])
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc0111dd7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[1. 0. 0.]]
# expectation CaoNguyen
